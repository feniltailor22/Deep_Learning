# %% [markdown]
# <a href="https://colab.research.google.com/github/feniltailor22/Deep_Learning/blob/main/Image_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img 
import cv2

# %%
datagen= ImageDataGenerator(
    rotation_range= 40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    horizontal_flip= True,
    fill_mode='nearest'
)

# %%
img= load_img('/content/orange.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F3D94F8A110>

# %%
img= img_to_array(img)

# %%
img
# Out:
# array([[[137., 174., 105.],
#         [140., 177., 107.],
#         [143., 181., 108.],
#         ...,
#         [244., 254., 255.],
#         [242., 252., 254.],
#         [240., 250., 252.]],
#
#        [[129., 166.,  97.],
#         [132., 169.,  99.],
#         [135., 173., 100.],
#         ...,
#         [242., 254., 252.],
#         [239., 251., 249.],
#         [236., 248., 244.]],
#
#        [[135., 172., 103.],
#         [136., 173., 104.],
#         [139., 177., 104.],
#         ...,
#         [185., 203., 191.],
#         [185., 201., 190.],
#         [183., 199., 186.]],
#
#        ...,
#
#        [[117., 107., 105.],
#         [117., 108., 103.],
#         [114., 105., 100.],
#         ...,
#         [ 68.,  67.,  72.],
#         [ 68.,  67.,  72.],
#         [ 68.,  67.,  72.]],
#
#        [[223., 208., 201.],
#         [223., 208., 201.],
#         [220., 205., 198.],
#         ...,
#         [ 68.,  67.,  73.],
#         [ 67.,  66.,  72.],
# ...

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)

# %%
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=307x307 at 0x7F3D9367EF50>

# %%
resized.shape
# Out:
# (307, 307, 3)

# %%
resized= resized.reshape(1,307,307,3)

# %%
i=0
for batch in datagen.flow(x=resized, batch_size=1, save_to_dir='/content/drive/MyDrive/My/preview', save_prefix='orange', save_format='jpeg'):
  i+= 1
  if i>20:
    break

# %%
gen_img_1= cv2.imread('/content/drive/MyDrive/My/preview/orange_0_1113.jpeg')

# %%
cv2_imshow(gen_img_1)
# Out:
# <PIL.Image.Image image mode=RGB size=307x307 at 0x7F3D8F4256D0>

# %%
gen_img_2= cv2.imread('/content/drive/MyDrive/My/preview/orange_0_1173.jpeg')
cv2_imshow(gen_img_2)
# Out:
# <PIL.Image.Image image mode=RGB size=307x307 at 0x7F3D8F40ABD0>

# %%
gen_img_3= cv2.imread('/content/drive/MyDrive/My/preview/orange_0_2667.jpeg')
cv2_imshow(gen_img_3)
# Out:
# <PIL.Image.Image image mode=RGB size=307x307 at 0x7F3D8F4E0C50>

# %%
gen_img_4= cv2.imread('/content/drive/MyDrive/My/preview/orange_0_4960.jpeg')
cv2_imshow(gen_img_4)
# Out:
# <PIL.Image.Image image mode=RGB size=307x307 at 0x7F3D8F423910>

# %%
gen_img_5= cv2.imread('/content/drive/MyDrive/My/preview/orange_0_6620.jpeg')
cv2_imshow(gen_img_5)
# Out:
# <PIL.Image.Image image mode=RGB size=307x307 at 0x7F3D8F41F390>
